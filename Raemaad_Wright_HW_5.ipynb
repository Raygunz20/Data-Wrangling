# %% [markdown]
# <a href="https://colab.research.google.com/github/Raygunz20/Data-Wrangling/blob/main/Raemaad_Wright_HW_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# import python packages
import pandas as pd
print("import package libraries")
# Out:
# import package libraries

# %%
# load dataset
tree_census = pd.read_csv('trees.csv')
print("load dataset may take long to load")
# Out:
# load dataset may take long to load

# %%
# look at the first five rows
tree_census.head()
# Out:
#    created_at  tree_id block_id  \
# 0  08/27/2015  180,683  348,711
# 1  09/03/2015  200,540  315,986
# 2  09/05/2015  204,026  218,365
# 3  09/05/2015  204,337  217,969
# 4  08/30/2015  189,565  223,043
#
#                                         the_geom  tree_dbh  stump_diam  \
# 0  POINT (-73.84421521958048 40.723091773924274)         3           0
# 1   POINT (-73.81867945834878 40.79411066708779)        21           0
# 2  POINT (-73.93660770459083 40.717580740099116)         3           0
# 3  POINT (-73.93445615919741 40.713537494833226)        10           0
# 4   POINT (-73.97597938483258 40.66677775537875)        21           0
#
#   curb_loc status health                           spc_latin  ... st_assem  \
# 0   OnCurb  Alive   Fair                         Acer rubrum  ...       28
# 1   OnCurb  Alive   Fair                   Quercus palustris  ...       27
# 2   OnCurb  Alive   Good  Gleditsia triacanthos var. inermis  ...       50
# 3   OnCurb  Alive   Good  Gleditsia triacanthos var. inermis  ...       53
# 4   OnCurb  Alive   Good                     Tilia americana  ...       44
#
#   st_senate   nta            nta_name  boro_ct     state   Latitude  \
# 0        16  QN17        Forest Hills  4073900  New York  40.723092
# 1        11  QN49          Whitestone  4097300  New York  40.794111
# 2        18  BK90   East Williamsburg  3044900  New York  40.717581
# 3        18  BK90   East Williamsburg  3044900  New York  40.713537
# 4        21  BK37  Park Slope-Gowanus  3016500  New York  40.666778
#
#    longitude             x_sp            y_sp
# 0 -73.844215  1,027,431.14821  202,756.768749
# 1 -73.818679  1,034,455.70109  228,644.837379
# 2 -73.936608  1,001,822.83131  200,716.891267
# 3 -73.934456  1,002,420.35833  199,244.253136
# 4 -73.975979   990,913.775046  182,202.425999
#
# [5 rows x 42 columns]

# %%
# look at the last five rows
tree_census.tail()
# Out:
#         created_at  tree_id block_id  \
# 683783  08/18/2015  155,433  217,978
# 683784  08/29/2015  183,795  348,185
# 683785  08/22/2015  166,161  401,670
# 683786  08/29/2015  184,028  504,204
# 683787  09/03/2015  200,607  306,527
#
#                                              the_geom  tree_dbh  stump_diam  \
# 683783    POINT (-73.95494401022562 40.7132107823145)        25           0
# 683784   POINT (-73.85665019989099 40.71519444267162)         7           0
# 683785   POINT (-74.13651724205825 40.62076152739799)        12           0
# 683786  POINT (-73.90311472453581 40.850828186655754)         9           0
# 683787   POINT (-73.78752645502483 40.73216525220126)        23           0
#
#        curb_loc status health            spc_latin  ... st_assem st_senate  \
# 683783   OnCurb  Alive   Good    Quercus palustris  ...       53        18
# 683784   OnCurb  Alive   Good  Cladrastis kentukea  ...       28        15
# 683785   OnCurb  Alive   Good          Acer rubrum  ...       63        24
# 683786   OnCurb  Alive   Good          Acer rubrum  ...       86        33
# 683787   OnCurb  Alive   Fair          Acer rubrum  ...       25        11
#
#          nta               nta_name  boro_ct     state   Latitude  longitude  \
# 683783  BK73  North Side-South Side  3051900  New York  40.713211 -73.954944
# 683784  QN17           Forest Hills  4070700  New York  40.715194 -73.856650
# 683785  SI07            Westerleigh  5020100  New York  40.620762 -74.136517
# 683786  BX41             Mount Hope  2023502  New York  40.850828 -73.903115
# 683787  QN41   Fresh Meadows-Utopia  4134100  New York  40.732165 -73.787526
#
#                    x_sp            y_sp
# 683783   996,740.685965  199,121.636255
# 683784  1,023,989.07438  199,873.647547
# 683785   946,351.410431   165,466.07627
# 683786  1,011,053.64553  249,271.950653
# 683787  1,043,136.35794  206,095.538318
#
# [5 rows x 42 columns]

# %%
# list of column names
tree_census.columns
# Out:
# Index(['created_at', 'tree_id', 'block_id', 'the_geom', 'tree_dbh',
#        'stump_diam', 'curb_loc', 'status', 'health', 'spc_latin', 'spc_common',
#        'steward', 'guards', 'sidewalk', 'user_type', 'problems', 'root_stone',
#        'root_grate', 'root_other', 'trnk_wire', 'trnk_light', 'trnk_other',
#        'brnch_ligh', 'brnch_shoe', 'brnch_othe', 'address', 'zipcode',
#        'zip_city', 'cb_num', 'borocode', 'boroname', 'cncldist', 'st_assem',
#        'st_senate', 'nta', 'nta_name', 'boro_ct', 'state', 'Latitude',
#        'longitude', 'x_sp', 'y_sp'],
#       dtype='object')

# %%
# identify the size, number of rows and columns in the dataset
tree_census.shape
# Out:
# (683788, 42)

# %%
# summary of the dataset
tree_census.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 683788 entries, 0 to 683787
# Data columns (total 42 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   created_at  683788 non-null  object
#  1   tree_id     683788 non-null  object
#  2   block_id    683788 non-null  object
#  3   the_geom    683788 non-null  object
#  4   tree_dbh    683788 non-null  int64
#  5   stump_diam  683788 non-null  int64
#  6   curb_loc    683788 non-null  object
#  7   status      683788 non-null  object
#  8   health      652172 non-null  object
#  9   spc_latin   652169 non-null  object
#  10  spc_common  652169 non-null  object
#  11  steward     164350 non-null  object
#  12  guards      79866 non-null   object
#  13  sidewalk    652172 non-null  object
#  14  user_type   683788 non-null  object
#  15  problems    225844 non-null  object
#  16  root_stone  683788 non-null  object
#  17  root_grate  683788 non-null  object
#  18  root_other  683788 non-null  object
#  19  trnk_wire   683788 non-null  object
#  20  trnk_light  683788 non-null  object
#  21  trnk_other  683788 non-null  object
#  22  brnch_ligh  683788 non-null  object
#  23  brnch_shoe  683788 non-null  object
#  24  brnch_othe  683788 non-null  object
#  25  address     683788 non-null  object
#  26  zipcode     683788 non-null  int64
#  27  zip_city    683788 non-null  object
#  28  cb_num      683788 non-null  int64
#  29  borocode    683788 non-null  int64
#  30  boroname    683788 non-null  object
#  31  cncldist    683788 non-null  int64
#  32  st_assem    683788 non-null  int64
#  33  st_senate   683788 non-null  int64
#  34  nta         683788 non-null  object
#  35  nta_name    683788 non-null  object
#  36  boro_ct     683788 non-null  int64
#  37  state       683788 non-null  object
#  38  Latitude    683788 non-null  float64
#  39  longitude   683788 non-null  float64
#  40  x_sp        683788 non-null  object
#  41  y_sp        683788 non-null  object
# dtypes: float64(2), int64(9), object(31)
# memory usage: 219.1+ MB

# %%
# health status of trees
tree_census.health.value_counts(dropna=False)
# Out:
# health
# Good    528850
# Fair     96504
# NaN      31616
# Poor     26818
# Name: count, dtype: int64

# %%
# get status of trees
tree_census.status.value_counts(dropna=False)
# Out:
# status
# Alive    652173
# Stump     17654
# Dead      13961
# Name: count, dtype: int64

# %%
# subset of the original, removed columns not interested in
trees_subset = tree_census[['tree_id', 'tree_dbh', 'stump_diam', 'curb_loc', 'status', 'health',
                            'spc_latin', 'spc_common', 'steward', 'guards', 'sidewalk', 'user_type',
                            'problems', 'root_stone', 'root_grate', 'root_other', 'trnk_wire', 'trnk_light',
                            'trnk_other', 'brnch_ligh', 'brnch_shoe', 'brnch_othe']]

# list the first 5 rows of the new subset
trees_subset.head()
# Out:
#    tree_id  tree_dbh  stump_diam curb_loc status health  \
# 0  180,683         3           0   OnCurb  Alive   Fair
# 1  200,540        21           0   OnCurb  Alive   Fair
# 2  204,026         3           0   OnCurb  Alive   Good
# 3  204,337        10           0   OnCurb  Alive   Good
# 4  189,565        21           0   OnCurb  Alive   Good
#
#                             spc_latin       spc_common steward guards  ...  \
# 0                         Acer rubrum        red maple     NaN    NaN  ...
# 1                   Quercus palustris          pin oak     NaN    NaN  ...
# 2  Gleditsia triacanthos var. inermis      honeylocust    1or2    NaN  ...
# 3  Gleditsia triacanthos var. inermis      honeylocust     NaN    NaN  ...
# 4                     Tilia americana  American linden     NaN    NaN  ...
#
#   problems root_stone root_grate root_other trnk_wire trnk_light trnk_other  \
# 0      NaN         No         No         No        No         No         No
# 1   Stones        Yes         No         No        No         No         No
# 2      NaN         No         No         No        No         No         No
# 3   Stones        Yes         No         No        No         No         No
# 4   Stones        Yes         No         No        No         No         No
#
#   brnch_ligh brnch_shoe brnch_othe
# 0         No         No         No
# 1         No         No         No
# 2         No         No         No
# 3         No         No         No
# 4         No         No         No
#
# [5 rows x 22 columns]

# %%
# check for any null values
trees_subset.isna().sum()
# Out:
# tree_id            0
# tree_dbh           0
# stump_diam         0
# curb_loc           0
# status             0
# health         31616
# spc_latin      31619
# spc_common     31619
# steward       519438
# guards        603922
# sidewalk       31616
# user_type          0
# problems      457944
# root_stone         0
# root_grate         0
# root_other         0
# trnk_wire          0
# trnk_light         0
# trnk_other         0
# brnch_ligh         0
# brnch_shoe         0
# brnch_othe         0
# dtype: int64

# %%
# show all that are none values in health, alot of missing values NaN
tree_census.describe()
# Out:
#             tree_dbh     stump_diam        zipcode         cb_num  \
# count  683788.000000  683788.000000  683788.000000  683788.000000
# mean       11.279787       0.432463   10916.246044     343.505404
# std         8.723042       3.290241     651.553364     115.740601
# min         0.000000       0.000000      83.000000     101.000000
# 25%         4.000000       0.000000   10451.000000     302.000000
# 50%         9.000000       0.000000   11214.000000     402.000000
# 75%        16.000000       0.000000   11365.000000     412.000000
# max       450.000000     140.000000   11697.000000     503.000000
#
#             borocode       cncldist       st_assem      st_senate  \
# count  683788.000000  683788.000000  683788.000000  683788.000000
# mean        3.358500      29.943181      50.791583      20.615781
# std         1.166746      14.328531      18.966520       7.390844
# min         1.000000       1.000000      23.000000      10.000000
# 25%         3.000000      19.000000      33.000000      14.000000
# 50%         4.000000      30.000000      52.000000      21.000000
# 75%         4.000000      43.000000      64.000000      25.000000
# max         5.000000      51.000000      87.000000      36.000000
#
#             boro_ct       Latitude      longitude
# count  6.837880e+05  683788.000000  683788.000000
# mean   3.404914e+06      40.701261     -73.924060
# std    1.175863e+06       0.090311       0.123583
# min    1.000201e+06      40.498466     -74.254965
# 25%    3.011700e+06      40.631928     -73.980500
# 50%    4.008100e+06      40.700612     -73.912911
# 75%    4.103202e+06      40.762228     -73.834910
# max    5.032300e+06      40.912918     -73.700488

# %%
# generate histogram of data distribution
trees_subset.hist(bins=60, figsize=(20,10))
# Out:
# array([[<Axes: title={'center': 'tree_dbh'}>,
#         <Axes: title={'center': 'stump_diam'}>]], dtype=object)

# %%
# trees larger than 50
big_trees = trees_subset[trees_subset['tree_dbh']> 50]
big_trees.head()
# Out:
#        tree_id  tree_dbh  stump_diam        curb_loc status health  \
# 2385   168,583       425           0          OnCurb  Alive   Good
# 3724   199,546        51           0          OnCurb  Alive   Good
# 4874   139,665        72           0  OffsetFromCurb  Alive   Good
# 6711   209,349       122           0          OnCurb  Alive   Good
# 10053  215,075       169           0          OnCurb  Alive   Good
#
#                                 spc_latin       spc_common steward guards  \
# 2385                      Quercus bicolor  swamp white oak    1or2    NaN
# 3724                     Acer saccharinum     silver maple     NaN    NaN
# 4874                     Acer saccharinum     silver maple     NaN    NaN
# 6711                    Quercus palustris          pin oak     NaN    NaN
# 10053  Gleditsia triacanthos var. inermis      honeylocust     NaN    NaN
#
#        ... problems root_stone root_grate root_other trnk_wire trnk_light  \
# 2385   ...      NaN         No         No         No        No         No
# 3724   ...   Stones        Yes         No         No        No         No
# 4874   ...      NaN         No         No         No        No         No
# 6711   ...      NaN         No         No         No        No         No
# 10053  ...      NaN         No         No         No        No         No
#
#       trnk_other brnch_ligh brnch_shoe brnch_othe
# 2385          No         No         No         No
# 3724          No         No         No         No
# 4874          No         No         No         No
# 6711          No         No         No         No
# 10053         No         No         No         No
#
# [5 rows x 22 columns]

# %%
# box plot
tree_census.boxplot(column='tree_dbh', by='stump_diam')
# Out:
# <Axes: title={'center': 'tree_dbh'}, xlabel='stump_diam'>

# %%
# scatter plot
big_trees[['tree_id', 'tree_dbh']].plot(kind='scatter', x='tree_id', y='tree_dbh')
# Out:
# <Axes: xlabel='tree_id', ylabel='tree_dbh'>
